# %%
def add(l1,l2):
    n1 = len(l1)
    n2 = len(l2)
    i=0
    while i<n1 or i<n2:
        result = n1[i]+n2[i]
        i+=1
l1 = [1,2,3,4,5]
l2 = [1,2,3,4,5]
print(add(l1,l2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       8 l1 = [1,2,3,4,5]
#       9 l2 = [1,2,3,4,5]
# ---> 10 print(add(l1,l2))
#
# Cell In[7], line 6, in add(l1, l2)
#       4 i=0
#       5 while i<n1 or i<n2:
# ----> 6     result = n1[i]+n2[i]
#       7     i+=1
#
# TypeError: 'int' object is not subscriptable
